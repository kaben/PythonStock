# %%
import numpy as np
import pandas as pd
import datetime
import pandas_datareader.data as web
goog = web.DataReader('GOOG','google', start=datetime.datetime(2009,3,18),end=(2016,12,16))
goog.tail()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-1-024ee4bc52d0> in <module>()
#       3 import datetime
#       4 import pandas_datareader.data as web
# ----> 5 goog = web.DataReader('GOOG','google', start=datetime.datetime(2009,3,18),end=(2016,12,16))
#       6 goog.tail()
#
# /Users/cpc4/anaconda/envs/snakes27/lib/python2.7/site-packages/pandas_datareader/data.pyc in DataReader(name, data_source, start, end, retry_count, pause, session)
#     103                                  chunksize=25,
#     104                                  retry_count=retry_count, pause=pause,
# --> 105                                  session=session).read()
#     106
#     107     elif data_source == "fred":
#
# /Users/cpc4/anaconda/envs/snakes27/lib/python2.7/site-packages/pandas_datareader/base.pyc in read(self)
#     171         # If a single symbol, (e.g., 'GOOG')
# ...

# %%
import numpy as np
import pandas as pd
import datetime
import pandas_datareader.data as web
goog = web.DataReader('GOOG','yahoo', start=datetime.datetime(2009,3,18),end=(2016,12,16))
goog.tail()
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-2-bad0f3bd279e> in <module>()
#       3 import datetime
#       4 import pandas_datareader.data as web
# ----> 5 goog = web.DataReader('GOOG','yahoo', start=datetime.datetime(2009,3,18),end=(2016,12,16))
#       6 goog.tail()
#
# /Users/cpc4/anaconda/envs/snakes27/lib/python2.7/site-packages/pandas_datareader/data.pyc in DataReader(name, data_source, start, end, retry_count, pause, session)
#      92                                 adjust_price=False, chunksize=25,
#      93                                 retry_count=retry_count, pause=pause,
# ---> 94                                 session=session).read()
#      95
#      96     elif data_source == "yahoo-actions":
#
# /Users/cpc4/anaconda/envs/snakes27/lib/python2.7/site-packages/pandas_datareader/yahoo/daily.pyc in read(self)
#      75     def read(self):
# ...

# %% [markdown]
# Pseudocode:
# loop through pricing
# if consecutive days of same trend up or down are > 3 (or set threshold)
#     do:
#     print (streak for #ticker is #days #up(down)
#     print This has happened #times since #date_of_start_of_data
#     print (average returns for #times is % for 1 week and % for 1 month)
#     print (current return bar chart for #days)
#     print (bar charts and line projections for returns over next 1 week and 1 month)
#
# Next steps: evaluate the trend not in terms of absolute positive or negative returns, but vs an ETF . . .and print the same information.
#
# Additional step - evaluate the 1wk and 1month subsequent returns vs oil price returns over that same time period - to see if the trend was stock-specific or just a reflection of oil prices.
